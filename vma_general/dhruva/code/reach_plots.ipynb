# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib as plt

# %% [markdown]
# ### Participant 1

# %%
sub1 = pd.read_csv('../data/data_movements_0.csv')
sns.lineplot(data = sub1.loc[sub1.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 2

# %%
sub2 = pd.read_csv('../data/data_movements_1.csv')
sns.lineplot(data = sub2.loc[sub2.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 3

# %%
sub3 = pd.read_csv('../data/data_movements_2.csv')
sns.lineplot(data = sub3.loc[sub3.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 4

# %%
sub4 = pd.read_csv('../data/data_movements_3.csv')
sns.lineplot(data = sub4.loc[sub4.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 5

# %%
sub5 = pd.read_csv('../data/data_movements_4.csv')
sns.lineplot(data = sub5.loc[sub5.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 6

# %%
sub6 = pd.read_csv('../data/data_movements_5.csv')
sns.lineplot(data = sub6.loc[sub6.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 7

# %%
sub7 = pd.read_csv('../data/data_movements_6.csv')
sns.lineplot(data = sub7.loc[sub7.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 8

# %%
sub8 = pd.read_csv('../data/data_movements_7.csv')
sns.lineplot(data = sub8.loc[sub8.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 9

# %%
sub9 = pd.read_csv('../data/data_movements_8.csv')
sns.lineplot(data = sub9.loc[sub9.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 10

# %%
sub10 = pd.read_csv('../data/data_movements_9.csv')
sns.lineplot(data = sub10.loc[sub10.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 11

# %%
sub11 = pd.read_csv('../data/data_movements_10.csv')
sns.lineplot(data = sub11.loc[sub11.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Participant 12

# %%
sub12 = pd.read_csv('../data/data_movements_11.csv')
sns.lineplot(data = sub12.loc[sub12.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>
