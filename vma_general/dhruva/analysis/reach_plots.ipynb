# %%
import seaborn as sns 
import pandas as pd 
import numpy as np
import matplotlib as plt

# %% [markdown]
# Participant 1 Reaches - replication

# %%
figure_1 = pd.read_csv('../data/data_movements_1.csv')
sns.lineplot(data = figure_1.loc[figure_1.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 2 Reaches - aiming

# %%
figure_2 = pd.read_csv('../data/data_movements_2.csv')
sns.lineplot(data = figure_2.loc[figure_2.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 3 Reaches - replication

# %%
figure_3 = pd.read_csv('../data/data_movements_3.csv')
sns.lineplot(data = figure_3.loc[figure_3.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 4 - replication

# %%
figure_4 = pd.read_csv('../data/data_movements_4.csv')
sns.lineplot(data = figure_4.loc[figure_4.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 5 - replication

# %%
figure_5 = pd.read_csv('../data/data_movements_5.csv')
sns.lineplot(data = figure_5.loc[figure_5.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 6 - replication

# %%
figure_6 = pd.read_csv('../data/data_movements_6.csv')
sns.lineplot(data = figure_6.loc[figure_6.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 7 - Replication

# %%
figure_7 = pd.read_csv('../data/data_movements_7.csv')
sns.lineplot(data = figure_7.loc[figure_7.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 8 - aiming (updated instructions at start and before washout - no pause after baseline to give instructions)

# %%
figure_8 = pd.read_csv('../data/data_movements_8.csv')
sns.lineplot(data = figure_8.loc[figure_8.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Participant 9 - Aiming

# %%
figure_9 = pd.read_csv('../data/data_movements_9.csv')
sns.lineplot(data = figure_9.loc[figure_9.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>
