# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv(r"C:\Users\laura\OneDrive\Desktop\Honours thesis - data collection\Participant data\cleaned data\average_45_pID_5_s2.csv")

# Create a scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(df['target'], df['average'], marker='o')
plt.xlabel("Testing target angles")
plt.ylabel("Average difference, in degrees, between the target and hand angle")
plt.title("Generalisation function")

# Show the plot
plt.grid(True)
plt.show()
