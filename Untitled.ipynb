# %%
import seaborn as sns 
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
participant = 1
figure_1 = pd.read_csv('/Users/liamturpin/mq_honours_2023/vma_general/liam/data/data_movements_0.csv')
sns.lineplot(data = figure_1.loc[figure_1.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
figure_1 = pd.read_csv('/Users/liamturpin/mq_honours_2023/vma_general/liam/data/data_movements_1.csv')
sns.lineplot(data = figure_1.loc[figure_1.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
figure_1 = pd.read_csv('/Users/liamturpin/mq_honours_2023/vma_general/liam/data/data_movements_2.csv')
sns.lineplot(data = figure_1.loc[figure_1.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
figure_1 = pd.read_csv('/Users/liamturpin/mq_honours_2023/vma_general/liam/data/data_movements_3.csv')
sns.lineplot(data = figure_1.loc[figure_1.state == 'reach'], x = 'x', y = 'y', hue = 'trial', sort = False)
# Out:
# <Axes: xlabel='x', ylabel='y'>
